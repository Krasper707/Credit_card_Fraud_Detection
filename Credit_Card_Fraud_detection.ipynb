# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
data=pd.read_csv("/content/creditcard.csv")

# %% [markdown]
# #Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# - No null values
# - Highly imbalanced dataset

# %% [markdown]
# ##Finding relationships in dataset 0_0

# %% [markdown]
# Lets see the class imbalance via  a graph

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=data["Class"],palette=["Green","Red"])
plt.title("Class Imbalance")
plt.grid(axis="y")
plt.show()
# Out:
# <ipython-input-9-52bf4d82f8fa>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data["Class"],palette=["Green","Red"])

# %% [markdown]
# Transaction amount

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=data["Class"], y=data["Amount"])
plt.title("Amount by Class")
plt.show()

# %% [markdown]
# Too much outliers, lets try to bring it down a bit using log function

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=data["Class"], y=data["Amount"])
plt.yscale("log")
plt.title("Transaction Amount by Class")
plt.show()

# %% [markdown]
# Fraud events tend to have lesser amounts than real/legitimate ones
#
#
# Some frauds occur at high amounts, though they are less.

# %%
plt.figure(figsize=(10, 5))
data["Time_minutes"] = data["Time"] / 60

sns.kdeplot(data[data["Class"] == 0]["Time_minutes"], label="Legit (0)", color="blue", fill=True)
sns.kdeplot(data[data["Class"] == 1]["Time_minutes"], label="Fraud (1)", color="red", fill=True)

plt.xlabel("Time (mins)")
plt.ylabel("Density")
plt.title("Transaction Time Distribution")
plt.legend()
plt.show()

# %% [markdown]
# - Fraud transactions occur at certain times, lets see it in terms of hours

# %%
data["Time_Normalized"] = data["Time"] - data["Time"].min()

data["Hour"] = (data["Time_Normalized"] // 3600) % 24

plt.figure(figsize=(10, 5))

sns.kdeplot(data[data["Class"] == 0]["Hour"], label="Legit (0)", color="blue", fill=True)
sns.kdeplot(data[data["Class"] == 1]["Hour"], label="Fraud (1)", color="red", fill=True)

plt.xlabel("Hour of the Day")
plt.ylabel("Density")
plt.title("Transaction Time Distribution (Hourly Pattern)")
plt.xticks(range(0, 24))
plt.legend()
plt.grid(axis="y", linestyle="--")
plt.show()

# %% [markdown]
# - Frauds occur more during business hours and early hours(0-4).
# - There are some spikes in the business hours(10-18)
# - These may give insights into why fraudulent transactions take place

# %%
plt.figure(figsize=(10, 5))

sns.heatmap(data.corr(), cmap="coolwarm", annot=False)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - There is a lot of correlation between Time and Class
#   - Could indicate fraudulent activity is time-dependent (e.g., late-night fraud spikes).
# - V6 and Amount also have considerable amount of correlation.
#
#   - V6 could be a hidden indicator of fraud related to transaction amount.
#   - We Need to visualize V6 vs Amount for fraud and non-fraud transactions to check if high V6 values correlate with fraud.
#
#
# - V2,V3,V5 and Amount have negative correlation
#   - Need to plot scatter plots to check

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="Class", y="Amount", data=data,hue="Class", palette=["Green", "red"])
plt.yscale("log")
plt.xlabel("Class (0 = Legit, 1 = Fraud)")
plt.ylabel("Transaction Amount (Log Scale)")
plt.title("Transaction Amount Distribution by Fraud Class")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# - Fraud transactions are generally mid-sized in terms of amount, yet there exists outliers which are of 10^3 scale.
# - More outliers exist in case of Legitimate transactions

# %%
data["Time_Range"] = pd.cut(data["Hour"], bins=[0, 6, 12, 18, 24], labels=["Midnight-6AM", "Morning", "Afternoon", "Evening"])

plt.figure(figsize=(8, 5))

sns.countplot(x=data[data["Class"] == 1]["Time_Range"], palette=["red"])

plt.xlabel("Time Range")
plt.ylabel("Fraud Transaction Count")
plt.title("Fraud Distribution Across Different Time Ranges")
plt.grid(axis="y")

plt.show()
# Out:
# <ipython-input-16-1e409a6c5bb5>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[data["Class"] == 1]["Time_Range"], palette=["red"])
# <ipython-input-16-1e409a6c5bb5>:5: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x=data[data["Class"] == 1]["Time_Range"], palette=["red"])

# %% [markdown]
# - There seems to be uniform distribution of Fraudulent transactions till Morning.
# - The peak hours of fradulent transactions is found during the afternoon.
# - Very less amount of fraudulent transactions take place during evening

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data[data["Class"] == 1]["Amount"],
                y=data[data["Class"] == 1]["V6"],
                color="red", alpha=0.7)
plt.xlabel("Transaction Amount")
plt.ylabel("V6 Value")
plt.title("V6 vs Transaction Amount (Fraud vs Non-Fraud)")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# - Most fraud transactions occur at low transaction amounts (clustering near 0-500).
# - A few fraud cases exist at high amounts (above 1000), but they are rare.
# - V6 values seem to be spread across a range, but certain values appear more frequently near smaller transaction amounts.

# %%
df_numeric = data.select_dtypes(include=["number"])

corr_matrix = df_numeric.corr()

fraud_corr = corr_matrix["Class"].abs().sort_values(ascending=False)

print(fraud_corr[1:10])
# Out:
# V17    0.326481
# V14    0.302544
# V12    0.260593
# V10    0.216883
# V16    0.196539
# V3     0.192961
# V7     0.187257
# V11    0.154876
# V4     0.133447
# Name: Class, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

fraud_df = data[data["Class"] == 1][["V17", "V14", "V12", "V10", "V16"]]

scaler = StandardScaler()
fraud_scaled = scaler.fit_transform(fraud_df)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

kmeans = KMeans(n_clusters=3, random_state=42)
fraud_df["Cluster"] = kmeans.fit_predict(fraud_scaled)

plt.figure(figsize=(8, 5))
sns.scatterplot(x=fraud_df["V17"], y=fraud_df["V14"], hue=fraud_df["Cluster"], palette="viridis")
plt.xlabel("V17")
plt.ylabel("V14")
plt.title("K-Means Clustering of Fraud Transactions")
plt.show()

# %% [markdown]
# The clustering shows clear separations among fraud transactions

# %%
fraud_df["Cluster"] = kmeans.labels_

cluster_summary = fraud_df.groupby("Cluster").mean()
print(cluster_summary)
# Out:
#                V17        V14        V12        V10        V16
# Cluster
# 0        -7.940863  -8.481377  -7.073612  -5.871045  -4.892267
# 1        -1.088237  -3.739788  -2.352036  -1.966059  -0.951271
# 2       -17.586253 -11.607243 -14.083055 -14.378394 -10.331704

# %% [markdown]
# Transaction amount per cluster

# %%
fraud_df["Amount"] = data[data["Class"] == 1]["Amount"]

plt.figure(figsize=(8, 5))
sns.boxplot(x=fraud_df["Cluster"], y=fraud_df["Amount"], palette="viridis")
plt.xlabel("Cluster")
plt.yscale("log")

plt.ylabel("Transaction Amount")
plt.title("Transaction Amount Distribution Across Fraud Clusters")
plt.show()
# Out:
# <ipython-input-22-4fb7e802d509>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=fraud_df["Cluster"], y=fraud_df["Amount"], palette="viridis")

# %%
cluster_std = fraud_df.groupby("Cluster").std()
print(cluster_std)
# Out:
#               V17       V14       V12       V10       V16      Amount
# Cluster
# 0        3.991318  2.392663  1.798084  1.730144  1.894884  177.104406
# 1        3.313067  2.788996  1.957274  1.882802  1.816759  329.670574
# 2        3.655930  4.452938  2.381224  3.254613  1.959425  173.650824

# %% [markdown]
# - Cluster 0:
#   - Lowest transaction amount (~₹177).
#   - Possibly small-scale fraudulent transactions.
# - Cluster 1:
#
#   - Highest transaction amount (~₹330).
#   - Might represent high-value fraud transactions.
# - Cluster 2:
#   - Highest V14 & V10 (very distinct)!
#   - Lower transaction amount (~₹173).
#   - Might represent a separate type of fraud pattern (e.g., multiple small transactions with specific feature behavior).

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 35 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Time             284807 non-null  float64
#  1   V1               284807 non-null  float64
#  2   V2               284807 non-null  float64
#  3   V3               284807 non-null  float64
#  4   V4               284807 non-null  float64
#  5   V5               284807 non-null  float64
#  6   V6               284807 non-null  float64
#  7   V7               284807 non-null  float64
#  8   V8               284807 non-null  float64
#  9   V9               284807 non-null  float64
#  10  V10              284807 non-null  float64
#  11  V11              284807 non-null  float64
#  12  V12              284807 non-null  float64
#  13  V13              284807 non-null  float64
#  14  V14              284807 non-null  float64
#  15  V15              284807 non-null  float64
# ...

# %% [markdown]
# # Class Imbalance and Data Preprocessing

# %%
from imblearn.under_sampling import RandomUnderSampler

data2 = data.copy()
X = data2.drop(columns=["Class", "Time_minutes",  "Hour", "Time_Normalized", "Time_Range"])  # ✅ Fix here
y = data2["Class"]

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

print("Class distribution after resampling:\n", pd.Series(y_resampled).value_counts())
# Out:
# Class distribution after resampling:
#  Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
print(f"Training size: {X_train.shape}, Test size: {X_test.shape}")
# Out:
# Training size: (787, 30), Test size: (197, 30)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9289340101522843
# Precision: 0.9565217391304348
# Recall: 0.8979591836734694
# F1 Score: 0.9263157894736842
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss")
xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)

print("XGBoost - Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("XGBoost - Precision:", precision_score(y_test, y_pred_xgb))
print("XGBoost - Recall:", recall_score(y_test, y_pred_xgb))
print("XGBoost - F1 Score:", f1_score(y_test, y_pred_xgb))
# Out:
# XGBoost - Accuracy: 0.934010152284264
# XGBoost - Precision: 0.956989247311828
# XGBoost - Recall: 0.9081632653061225
# XGBoost - F1 Score: 0.9319371727748691
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:45:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# Best Model- XGBoost

# %% [markdown]
# #Alternative way

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import numpy as np

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled, y_resampled)

importances = rf.feature_importances_
feature_names = X.columns
important_features = feature_names[np.argsort(importances)[-10:]]  # Top 10 features

print("Top 10 Important Features:", important_features)
# Out:
# Top 10 Important Features: Index(['V9', 'V2', 'V3', 'V11', 'V16', 'V12', 'V17', 'V4', 'V10', 'V14'], dtype='object')

# %%
from imblearn.under_sampling import RandomUnderSampler

data2 = data.copy()
X = data2.drop(columns=["Class", "Time_minutes", "Hour", "Time_Normalized", "Time_Range"])  # ✅ Fix here
y = data2["Class"]

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

print("Class distribution after resampling:\n", pd.Series(y_resampled).value_counts())
# Out:
# Class distribution after resampling:
#  Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (787, 30)
# Test set size: (197, 30)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss")
xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:45:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
def evaluate_model(model_name, y_true, y_pred):
    print(f"{model_name} Model Evaluation")
    print(classification_report(y_true, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_true, y_pred))

evaluate_model("Logistic Regression", y_test, y_pred_lr)
evaluate_model("Random Forest", y_test, y_pred_rf)
evaluate_model("XGBoost", y_test, y_pred_xgb)
# Out:
# Logistic Regression Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97        99
#            1       0.98      0.95      0.96        98
#
#     accuracy                           0.96       197
#    macro avg       0.96      0.96      0.96       197
# weighted avg       0.96      0.96      0.96       197
#
# Confusion Matrix:
# [[97  2]
#  [ 5 93]]
# Random Forest Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        99
#            1       0.97      0.94      0.95        98
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197
#
# Confusion Matrix:
# [[96  3]
#  [ 6 92]]
# XGBoost Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        99
# ...

# %% [markdown]
# - XGBoost is the best model so far.

# %% [markdown]
# Tuning Models using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rf_params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [5, 10, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
}

rf = RandomForestClassifier(random_state=42)
grid_search_rf = GridSearchCV(rf, rf_params, cv=3, scoring="f1", n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)

print("Best RF Parameters:", grid_search_rf.best_params_)
rf_best = grid_search_rf.best_estimator_
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# Best RF Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
from xgboost import XGBClassifier

xgb_params = {
    "learning_rate": [0.01, 0.1, 0.2],
    "max_depth": [3, 6, 10],
    "n_estimators": [100, 200, 300],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.7, 0.8, 1.0],
}

xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss")
grid_search_xgb = GridSearchCV(xgb, xgb_params, cv=3, scoring="f1", n_jobs=-1, verbose=2)
grid_search_xgb.fit(X_train, y_train)

print("Best XGB Parameters:", grid_search_xgb.best_params_)
xgb_best = grid_search_xgb.best_estimator_
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# Best XGB Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.7}
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:48:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
y_pred_rf_best = rf_best.predict(X_test)
y_pred_xgb_best = xgb_best.predict(X_test)

evaluate_model("Optimized Random Forest", y_test, y_pred_rf_best)
evaluate_model("Optimized XGBoost", y_test, y_pred_xgb_best)
# Out:
# Optimized Random Forest Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        99
#            1       0.99      0.93      0.96        98
#
#     accuracy                           0.96       197
#    macro avg       0.96      0.96      0.96       197
# weighted avg       0.96      0.96      0.96       197
#
# Confusion Matrix:
# [[98  1]
#  [ 7 91]]
# Optimized XGBoost Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        99
#            1       0.95      0.95      0.95        98
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197
#
# Confusion Matrix:
# [[94  5]
#  [ 5 93]]

# %% [markdown]
# #Model Saving

# %%
joblib.dump(rf_best, "fraud_detection_model.pkl")

model = joblib.load("fraud_detection_model.pkl")
